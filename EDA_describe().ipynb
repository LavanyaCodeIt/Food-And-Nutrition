# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('Recipe_Clean.csv')
data.shape
# Out:
# (6865, 13)

# %%
data.dtypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6871 entries, 0 to 6870
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Srno                    6871 non-null   int64
#  1   RecipeName              6871 non-null   object
#  2   TranslatedRecipeName    6871 non-null   object
#  3   Ingredients             6865 non-null   object
#  4   TranslatedIngredients   6865 non-null   object
#  5   PrepTimeInMins          6871 non-null   int64
#  6   CookTimeInMins          6871 non-null   int64
#  7   TotalTimeInMins         6871 non-null   int64
#  8   Servings                6871 non-null   int64
#  9   Cuisine                 6871 non-null   object
#  10  Course                  6871 non-null   object
#  11  Diet                    6871 non-null   object
#  12  Instructions            6871 non-null   object
#  13  TranslatedInstructions  6871 non-null   object
# ...

# %%
data.describe(include="all")
# Out:
#          Unnamed: 0     Recipe No          Recipe Name  \
# count   6865.000000   6865.000000                 6865
# unique          NaN           NaN                 6837
# top             NaN           NaN  Peanut Curry Recipe
# freq            NaN           NaN                    2
# mean    3435.648653   4904.034669                  NaN
# std     1983.458994   3479.580199                  NaN
# min        0.000000      1.000000                  NaN
# 25%     1718.000000   1956.000000                  NaN
# 50%     3436.000000   4305.000000                  NaN
# 75%     5152.000000   7360.000000                  NaN
# max     6870.000000  14211.000000                  NaN
#
#                                               Ingredients  \
# count                                                6865
# unique                                               6857
# top     12 Button mushrooms - (button or crimini varie...
# freq                                                    2
# ...

# %%
data['TranslatedRecipeName'].value_counts()
# Out:
# Pudina Chutney Recipe                                        2
# Lahori Aloo Recipe                                           2
# Vegetarian Malai Kebab Recipe                                2
# Cabbage Besan Fry Recipe                                     2
# Pepper Cauliflower Recipe                                    2
#                                                             ..
# Cheesy Pasta Casserole With Broccoli And Cheese Recipe       1
# Kothamalli Thovayal Recipe (Dry Coriander Leaves Chutney)    1
# Red Rice Dosa Recipe                                         1
# Roasted Potatoes With Za'atar Recipe                         1
# Masala Karela Recipe - Masala Karela                         1
# Name: TranslatedRecipeName, Length: 6843, dtype: int64

# %%
data.describe(include=[np.number])
# Out:
#                Srno  PrepTimeInMins  CookTimeInMins  TotalTimeInMins  \
# count   6871.000000     6871.000000     6871.000000      6871.000000
# mean    4902.979042       28.585213       30.832339        59.417552
# std     3479.531022       81.042007       34.019694        88.699940
# min        1.000000        0.000000        0.000000         0.000000
# 25%     1955.500000       10.000000       20.000000        30.000000
# 50%     4304.000000       15.000000       30.000000        40.000000
# 75%     7363.000000       20.000000       35.000000        55.000000
# max    14211.000000     2880.000000      900.000000      2925.000000
#
#           Servings
# count  6871.000000
# mean      5.611410
# std      26.221807
# min       1.000000
# 25%       4.000000
# 50%       4.000000
# 75%       4.000000
# max    1000.000000

# %%
data.describe(include=[np.object])
# Out:
#                                       RecipeName   TranslatedRecipeName  \
# count                                       6871                   6871
# unique                                      6870                   6843
# top     Roasted Vegetable Pasta Primavera Recipe  Pudina Chutney Recipe
# freq                                           2                      2
#
#                                               Ingredients  \
# count                                                6865
# unique                                               6856
# top     16 Whole Wheat Brown Bread,3 Tomatoes - choppe...
# freq                                                    2
#
#                                     TranslatedIngredients Cuisine Course  \
# count                                                6865    6871   6871
# unique                                               6857      82     20
# top     12 Button mushrooms - (button or crimini varie...  Indian  Lunch
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  Recipe No                                        Recipe Name  \
# 0           0          1                               Masala Karela Recipe
# 1           1          2                         Spicy Tomato Rice (Recipe)
# 2           2          3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3           3          4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4           4          5  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                          Ingredients  Preparation Time/Min  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...                    15
# 1  2-1 / 2 cups rice - cooked, 3 tomatoes, 3 teas...                     5
# 2  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...                    20
# 3  500 grams Chicken,2 Onion - chopped,1 Tomato -...                    15
# 4  1 tablespoon chana dal, 1 tablespoon white ura...                    10
#
# ...

# %%
data.set_index("Recipe No", inplace= True)
data
# Out:
#            Unnamed: 0                                        Recipe Name  \
# Recipe No
# 1                   0                               Masala Karela Recipe
# 2                   1                         Spicy Tomato Rice (Recipe)
# 3                   2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 4                   3  Gongura Chicken Curry Recipe - Andhra Style Go...
# 5                   4  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
# ...               ...                                                ...
# 14073            6866                        Goan Mushroom Xacuti Recipe
# 14107            6867        Sweet Potato & Methi Stuffed Paratha Recipe
# 14165            6868      Ullikadala Pulusu Recipe | Spring Onion Curry
# 14167            6869  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
# 14211            6870                                 Navrang Dal Recipe
#
#                                                  Ingredients  \
# Recipe No
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Recipe Name', 'Ingredients', 'Preparation Time/Min',
#        'Cooking Time/Min', 'Total Time/Min', 'Servings', 'Cuisine', 'Course',
#        'Diet', 'Instructions', 'Link'],
#       dtype='object')

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)
data.columns
# Out:
# Index(['Recipe Name', 'Ingredients', 'Preparation Time/Min',
#        'Cooking Time/Min', 'Total Time/Min', 'Servings', 'Cuisine', 'Course',
#        'Diet', 'Instructions', 'Link'],
#       dtype='object')

# %%
# Out:
# 82

# %%
#Can Course fall under Categorical variable?
data['Course'].nunique()
data['Course'].unique()
data['Course'].describe()
# Out:
# count      6865
# unique       20
# top       Lunch
# freq       1763
# Name: Course, dtype: object

# %%
data['Diet'].describe()
data['Diet'].unique()
# Out:
# array(['Diabetic Friendly', 'Vegetarian', 'High Protein Vegetarian',
#        'Non Vegeterian', 'High Protein Non Vegetarian', 'Eggetarian',
#        'Vegan', 'No Onion No Garlic (Sattvic)', 'Gluten Free',
#        'Sugar Free Diet'], dtype=object)

# %%
data['Cuisine'].unique()
data['Cuisine'].describe()
# Out:
# array(['Indian', 'South Indian Recipes', 'Andhra', 'Udupi', 'Mexican',
#        'Fusion', 'Continental', 'Bengali Recipes', 'Punjabi', 'Chettinad',
#        'Tamil Nadu', 'Maharashtrian Recipes', 'North Indian Recipes',
#        'Italian Recipes', 'Sindhi', 'Thai', 'Chinese', 'Kerala Recipes',
#        'Gujarati Recipes\ufeff', 'Coorg', 'Rajasthani', 'Asian',
#        'Middle Eastern', 'Coastal Karnataka', 'European', 'Kashmiri',
#        'Karnataka', 'Lucknowi', 'Hyderabadi', 'Side Dish', 'Goan Recipes',
#        'Arab', 'Assamese', 'Bihari', 'Malabar', 'Himachal', 'Awadhi',
#        'Cantonese', 'North East India Recipes', 'Sichuan', 'Mughlai',
#        'Japanese', 'Mangalorean', 'Vietnamese', 'British',
#        'North Karnataka', 'Parsi Recipes', 'Greek', 'Nepalese',
#        'Oriya Recipes', 'French', 'Indo Chinese', 'Konkan',
#        'Mediterranean', 'Sri Lankan', 'Haryana', 'Uttar Pradesh',
#        'Malvani', 'Indonesian', 'African', 'Shandong', 'Korean',
# ...

# %%
data
# Out:
#                                                  Recipe Name  \
# Recipe No
# 1                                       Masala Karela Recipe
# 2                                 Spicy Tomato Rice (Recipe)
# 3          Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 4          Gongura Chicken Curry Recipe - Andhra Style Go...
# 5          Andhra Style Alam Pachadi Recipe - Adrak Chutn...
# ...                                                      ...
# 14073                            Goan Mushroom Xacuti Recipe
# 14107            Sweet Potato & Methi Stuffed Paratha Recipe
# 14165          Ullikadala Pulusu Recipe | Spring Onion Curry
# 14167      Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
# 14211                                     Navrang Dal Recipe
#
#                                                  Ingredients  \
# Recipe No
# 1          6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...
# 2          2-1 / 2 cups rice - cooked, 3 tomatoes, 3 teas...
# ...
